# %%
# Cell 1 : Enum та імпорти
from enum import Enum
import random

class AnimalStatus(Enum):
    ACTIVE = "активна"
    SLEEPING = "спить"
    EATING = "їсть"

# %%
#Cell 2 : Класи
class Animal:
    def __init__(self, species, name, age):
        self.species = species    # Вид тварини
        self.name = name          # Ім'я
        self.age = age            # Вік
        self.status = AnimalStatus.ACTIVE

class Owner:
    def __init__(self, name):
        self.name = name
        self.animals = []         # Список тваринок

class Statistics:
    def __init__(self):
        self.activity_log = {}
        self.popularity = {}

# %%
# Cell 3 : Клас PetCenter
class PetCenter:
    def __init__(self):
        self.animals = []
        self.owners = []
        self.stats = Statistics()

    def add_animal(self, animal):
        self.animals.append(animal)

    def add_owner(self, owner):
        self.owners.append(owner)

    def give_animal(self, owner, animal):
        owner.animals.append(animal)
        
        # Статистика
        self.stats.activity_log[owner.name] = \
            self.stats.activity_log.get(owner.name, 0) + 1

        self.stats.popularity[animal.species] = \
            self.stats.popularity.get(animal.species, 0) + 1

    def change_status(self, animal):
        animal.status = random.choice(list(AnimalStatus))

    def print_statistics(self):
        print("Активність власників:")
        for owner, count in self.stats.activity_log.items():
            print(f"{owner}: {count} тваринок")

        print("\nПопулярність видів:")
        for species, count in self.stats.popularity.items():
            print(f"{species}: {count} разів")

# %%
#Cell 4 : Симуляція
def simulate_days(center, days=60):
    for _ in range(days):
        owner = random.choice(center.owners)
        animal = random.choice(center.animals)
        center.give_animal(owner, animal)
        center.change_status(animal)

# %%
#Cell 5 : Виконання 
center = PetCenter()

# Додаємо тварин
center.add_animal(Animal("Собака", "Берта", 4))
center.add_animal(Animal("Хом'як", "Джексон", 1))
center.add_animal(Animal("Кіт", "Кіті", 3))

# Додаємо власників
center.add_owner(Owner("Юля"))
center.add_owner(Owner("Андрій"))
center.add_owner(Owner("Марко"))

# Запускаємо симуляцію
simulate_days(center)

# Друкуємо статистику
center.print_statistics()

# %%
#Cell 6 : Створюємо базовий клас
# Виведіть тип створененого обєкта
class MyAnimals:
    pass

a = MyAnimals()
print(type(a))

# %%
#Cell 7 : Додатково
class MyAnimals:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} говорить!")
#Створюємо об'єкт
a = MyAnimals("Берта")
#Перевіряємо тип
print(type(a))
#Викликаємо метод
a.speak()

# %%
#Cell 8 : Порівняння простих даних з об'єктами
#Списки з даними тварин
animals = ["Собака", "Хомʼяк", "Кіт"]
name = ["Берта", "Джексон", "Чарлі"]
age = [3, 2, 6]
#Приклад простого виводу
print(f"В мене є тваринка {animals[0]} яку звати {name[0]} які {age[0]} років")

#Створюємо клас MyAnimals
class MyAnimals:
    def __init__(self, animals, name, age, mass=None) -> None:
        self.animals = animals
        self.name = name
        self.age = age
        self.mass = 0 if mass is None else mass
        print(f"В мене є тваринка {self.animals} яку звати {self.name} які {self.age} років")

#Створюємо об'єкти
a1 = MyAnimals("Собака", "Берта", 3, 30)
a2 = MyAnimals("Хомʼяк", "Джексон", 2, 1)
a3 = MyAnimals("Кіт", "Чарлі", 6, 3)

#Перейменовуємо об'єкти на зрозумілі імена 
dog = a1
hamster = a2
cat = a3

#Виводимо інформацію про всі тваринки
print("\nІнформація про всі тваринки:")
print(f"{dog.name} — {dog.animals}, {dog.age} років, {dog.mass} кг")
print(f"{hamster.name} — {hamster.animals}, {hamster.age} років, {hamster.mass} кг")
print(f"{cat.name} — {cat.animals}, {cat.age} років, {cat.mass} кг")

# %%
#Cell 9 : Методи класу
# застосуйте методи класу до всіх обєктів a1-a3
class MyAnimals:
    def __init__(self, animals, name, age, mass=None) -> None:
        print(f"В мене є тваринка {animals} яку звати {name} які {age} років")
        self.animals = animals
        self.name = name
        self.age = age
        self.mass = 0 if mass == None else mass

    def speak(self):
        if self.animals == "Кіт":
            return f"Моя Тваринка {self.animals} говорить Мяууу"
        elif self.animals == "Собака":
            return f"Моя Тваринка {self.animals} говорить Гавв"
        elif self.animals == "Хомʼяк":
            return f"Моя Тваринка {self.animals} говорить Пі-пі"
        else:
            return f"Моя Тваринка {self.animals} не розмовляє"

    def add_one_year(self):
        self.age += 1
        return f"Моя Тваринка {self.animals} прожила за мною один рік"


a1 = MyAnimals("Собака", "Берта", 3, 30)
a2 = MyAnimals("Хомʼяк", "Джексон", 2, 1)
a3 = MyAnimals(animals="Кіт", name="Чарлі", age=6, mass=3)

print(f"Тваринка {a1.animals}:", a1.speak())
print(f"Тваринка {a3.animals}:", a3.speak())

print(f"{a1.animals} живе зі мною {a1.age} років")
print(a1.add_one_year())
print(f"{a1.animals} живе зі мною {a1.age} років")

print(a1.age)

# %%
#Cell 10 : Змінні класу, глобальні змінні над всіма обєктами
# задайте декілька обєктів в циклі та виведіть глобальну змінну
class MyAnimals:
    total_animals = 0
    total_animal_types = set()

    def __init__(self, animals, name, age, mass=None) -> None:
        print(f"В мене є тваринка {animals} яку звати {name} які {age} років")
        self.animals = animals
        self.name = name
        self.age = age
        self.mass = 0 if mass == None else mass
        MyAnimals.total_animal_types.add(animals)
        MyAnimals.total_animals += 1


print(f"В мене зараз є тваринки {list(MyAnimals.total_animal_types)}, їх кількість {MyAnimals.total_animals}")
a1 = MyAnimals("Собака", "Берта", 3, 30)
MyAnimals("Хомʼяк", "Джексон", 2, 1)
MyAnimals("Кіт", "Чарлі", 6, 3)
print(f"В мене зараз є тваринки {list(MyAnimals.total_animal_types)}, їх кількість {MyAnimals.total_animals}")

print(f"Я доступаюсь до змінної класу з обєкта {a1.total_animal_types}")
a1.total_animal_types = {"Собака"}
print(f"Я доступаюсь до змінної класу з обєкта {a1.total_animal_types} та з класу {MyAnimals.total_animal_types}")

# %%
#Cell 11 : Статичні методи та змінна self
class MyAnimals:
    def __init__(self, animals, name, age) -> None:
        self.animals = animals
        self.name = name
        self.age = age

    def add_one_year(self):
        self.age += 1
        return f"Моя Тваринка {self.animals} прожила за мною один рік"

    @staticmethod
    def call_pet():
        return "Тваринка біжить до нас"


a1 = MyAnimals("Собака", "Берта", 3)
a2 = MyAnimals("Кіт", "Чарлі", 6)

print(f"Ми кличемо нашу тваринку за допомогою статичного методу з обєкту |{a1.call_pet()}| та з класу |{MyAnimals.call_pet()}|")

print(f"Викликаю метод з обєкту |{a1.add_one_year()}| та з класу |{MyAnimals.add_one_year(a1)}|")

# %%
#Cell 12 : Робота з properties
# додайте ще одну properties та виведіть її
from datetime import datetime

class MyAnimals:
    max_age = 20

    def __init__(self, animals, name, age) -> None:
        self.animals = animals
        self.name = name
        self.age = age

    @property
    def live_untill(self):
        return datetime.today().year - self.age + self.max_age

    def add_one_year(self):
        self.age += 1
        return f"Моя Тваринка {self.animals} прожила за мною один рік"


a1 = MyAnimals("Кіт", "Чарлі", 6)
print(f"Мій {a1.animals} будже зі мною до {a1.live_untill} року")
a1.add_one_year()
print(f"Мій {a1.animals} будже зі мною до {a1.live_untill} року")

# %%
#Cell 13 : Методи Класу
# допишіть метод класу який буде превіряти що атрибут name заданий з великої букви
class MyAnimals:
    total_csv = int(0)
    total_objects = int(0)

    def __init__(self, animals, name, age) -> None:
        self.animals = animals
        self.name = name
        self.age = age
        MyAnimals.total_objects += 1

    @classmethod
    def from_csv(cls, csv_data: str):
        cls.total_csv += 1
        animal, name, age = csv_data.split(",")
        return cls(animal, name, age)


a1 = MyAnimals.from_csv("Собака,Берта,3")
a2 = MyAnimals("Кіт", "Чарлі", 6)

print(f"Мій {a1.animals}, звати {a1.name}, має {a1.age} років")
print(f"Мій {a2.animals}, звати {a2.name}, має {a2.age} років")
print(f"Загальна кількість обєктів {MyAnimals.total_objects} а створених з csv формату {MyAnimals.total_csv}")

# %%
#Cell 14 :Магічні методи
class MyAnimals:
    def __init__(self, animals, name, age) -> None:
        self.animals = animals
        self.name = name
        self.age = age

    # Офіційне представлення об'єкта
    def __repr__(self) -> str:
        return f'MyAnimals("{self.animals}", "{self.name}", {self.age})'

    # Зручне для користувача представлення
    def __str__(self) -> str:
        return f"Це є обєкт {self.__repr__()}"


a1 = MyAnimals("Собака", "Берта", 3)
print(a1)

print(repr(a1))

str(a1)

# %%
#Cell 15 :Арифметичні методи
a = 2
b = 5
c = "C"

print(a + b, a - int(1), a * b, str(a) + c)
print(a.__add__(b), a.__sub__(int(1)), a.__mul__(b))


class MyAnimals:
    def __init__(self, animals, name, age) -> None:
        self.animals = animals
        self.name = name
        self.age = age

    def __sub__(self, obj):
        if isinstance(obj, MyAnimals):
            return f"Мій {self.name} покусав {obj.name}"
        elif isinstance(obj, int):
            self.age += obj
            return f"Мій {self.name} постарів на {obj} років, тепер йому {self.age}"
        return NotImplementedError

    def __gt__(self, obj):
        if isinstance(obj, MyAnimals):
            if self.age > obj.age:
                return f"Старшим є {self.name}"
            return f"{self.name} не є старшим за {obj.name}"
        return NotImplementedError

    def __len__(self) -> int:
        print("Ми зайшли в метод len, та знаходимо довжину імені тваринки")
        return len(self.name)


a = MyAnimals("Собака", "Берта", 3)
b = MyAnimals("Кіт", "Чарлі", 6)

print(a - b)
print(a - 1)
print(a - float(1))

print(a > b)
print(b > a)

len(a)
